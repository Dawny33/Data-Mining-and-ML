# %%
import numpy as np
import pandas as pd
df = pd.ExcelFile("D:\\R dir\\first ex\\Data Exercise.xlsx")
df = df.parse("Sheet1",index_col=None, na_values=['NA'])
df.shape
# Out:
# (400, 6)

# %%
print df.columns
# Out:
# Index([u'input var 1', u'Input var 2', u'input var 3', u'Input var 4', u'Input var 5', u'Output var'], dtype='object')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['test']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
df.columns  = df.columns.map(lambda x: x.lower())

# %%
df.columns = ["inp1", "inp2", "inp3", "inp4", "inp5", "op"]

# %%
plt.scatter(df["inp1"], df["op"])

# %%
plt.bar(df["inp2"], df["op"])
# Out:
# <Container object of 400 artists>

# %%
plt.bar(df["inp3"], df["op"])
# Out:
# <Container object of 400 artists>

# %%
plt.scatter(df["inp4"], df["op"])

# %%
plt.scatter(df["inp5"], df["op"])

# %%
print df.describe()
# Out:
#              inp1        inp2        inp3         inp4       inp5           op
# count  400.000000  400.000000  400.000000   400.000000  400.00000    400.00000
# mean   118.190000   45.500000   44.655000   131.275940   35.10750   4992.21375
# std     53.222462    3.904884   30.217275   310.993450   24.60232   2964.46257
# min     23.000000   36.000000    1.000000     0.696976    1.00000    492.00000
# 25%     71.000000   43.000000   11.750000     8.423678   15.75000   2561.25000
# 50%    121.500000   45.500000   47.000000    31.017826   31.00000   4619.75000
# 75%    163.000000   48.000000   67.250000   100.541538   49.00000   6714.00000
# max    212.000000   55.000000  100.000000  3727.836553   99.00000  13248.00000
#
# [8 rows x 6 columns]

# %%
print np.max(df["inp4"])
# Out:
# 3727.83655292

# %%
train = df[0:300]
test = df[301:401]

# %%
print train.shape
print test.shape
# Out:
# (300, 6)
# (99, 6)

# %%
req_colmn = ["inp1", "inp3", "inp2"]

train_X = train[req_colmn]
train_Y = train["op"]

# %%
import sklearn
from sklearn import linear_model

reg1 = linear_model.LinearRegression()

# %%
reg1.fit(train_X, train_Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)

# %%
print reg1.coef_
# Out:
# [ 42.24193513  57.06950139  32.12419777]

# %%
X_test = test[req_colmn]
Y_test = test["op"]
error = np.mean((reg1.predict(X_test) - Y_test) ** 2)

# %%
print reg1.score(X_test, Y_test)
print error
print sklearn.metrics.mean_squared_error(Y_test, reg1.predict(X_test))
print sklearn.metrics.mean_absolute_error(Y_test, reg1.predict(X_test))
print sklearn.metrics.explained_variance_score(Y_test, reg1.predict(X_test))
# Out:
# 0.917216380895
# 684309.868773
# 684309.868773
# 642.548732424
# 0.919685620221

# %%
print reg1.predict(X_test).astype(float)
# Out:
# [  5.89587975e+03  -6.12033371e+02   4.74166145e+03   2.48462905e+03
#    5.86806421e+03   9.93396859e+03   3.12444198e+03   4.96538932e+03
#    4.64223916e+03   7.24305837e+03   7.86875500e+03   5.08261369e+03
#   -6.26214149e+00   4.48034604e+03  -4.04365667e+02   6.95881012e+03
#    5.20695221e+03   1.07198850e+04   5.18811290e+03   7.24753990e+03
#    2.07068980e+03   7.30065308e+03   7.16243973e+03   8.05640236e+03
#    3.26836015e+03   4.65642407e+03   3.61511216e+03   9.88253530e+03
#    7.70612155e+03   6.44756258e+03   4.44521439e+03   6.07713739e+03
#    3.73217683e+03   5.79718462e+03   6.52541525e+03   6.13891672e+03
#    9.41649103e+03   2.11718496e+03   1.05803804e+03   6.86796947e+03
#    2.70541808e+03   8.82733153e+03   2.37204590e+03   7.58370440e+03
#    8.75613254e+03   4.36510778e+03   8.33348489e+03   1.94244766e+03
#    7.08151100e+03   6.00114680e+03   5.79973546e+03   8.18095600e+03
#    2.78680341e+03   1.13876507e+04   2.80942617e+03   7.91462068e+03
#    6.20080691e+03   8.82965407e+03   7.19888575e+03   9.39331671e+03
#    4.53463639e+03   7.91800295e+03   2.84233022e+03   5.42602569e+03
#    5.02345381e+03   4.67287610e+03   8.53797227e+03   9.67986559e+02
#    1.50879814e+03   4.40591130e+03   8.22189673e+03   1.46748258e+03
#    7.21163226e+03   7.46926849e+03   3.52226836e+03   6.63948566e+03
#    5.08987436e+03   6.85610324e+03   4.57895939e+03   3.83830166e+03
#    7.15323520e+03   8.39463474e+03   9.19624970e+03   9.09947593e+03
#    1.65483304e+03   5.33493697e+03   6.40378728e+03   4.50336998e+03
#    7.36971558e+03   1.68511765e+03   4.10627076e+03   2.85508990e+03
#    3.90185197e+03   6.74604459e+03   4.48537527e+03   5.73045398e+03
#    4.50630882e+03   3.81067216e+03   9.17867650e+02]

# %%
plt.scatter(Y_test, Y_test - reg1.predict(X_test))
plt.xlabel("Actual")
plt.ylabel("Predicted")

# %%
df.corr()
# Out:
#           inp1      inp2      inp3      inp4      inp5        op
# inp1  1.000000  0.059067 -0.024177  0.209904 -0.040642  0.770502
# inp2  0.059067  1.000000 -0.003314  0.003665  0.026206  0.092746
# inp3 -0.024177 -0.003314  1.000000  0.200235  0.097824  0.549410
# inp4  0.209904  0.003665  0.200235  1.000000  0.117607  0.300904
# inp5 -0.040642  0.026206  0.097824  0.117607  1.000000  0.037720
# op    0.770502  0.092746  0.549410  0.300904  0.037720  1.000000
#
# [6 rows x 6 columns]

# %%
import statsmodels.formula.api as smf
mod2 = smf.wls(formula='op ~ inp1 + inp2 + inp3 ', data=train)

# %%
reg = mod2.fit()
print reg.summary()
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                     op   R-squared:                       0.917
# Model:                            WLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                     1097.
# Date:                Fri, 23 May 2014   Prob (F-statistic):          5.86e-160
# Time:                        17:21:27   Log-Likelihood:                -2451.4
# No. Observations:                 300   AIC:                             4911.
# Df Residuals:                     296   BIC:                             4926.
# Df Model:                           3
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -3975.1079    585.733     -6.787      0.000     -5127.837 -2822.378
# inp1          42.2419      0.945     44.698      0.000        40.382    44.102
# inp2          32.1242     12.786      2.513      0.013         6.962    57.286
# inp3          57.0695      1.614     35.353      0.000        53.893    60.246
# ==============================================================================
# Omnibus:                        0.998   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.607   Jarque-Bera (JB):                0.733
# Skew:                           0.051   Prob(JB):                        0.693
# Kurtosis:                       3.219   Cond. No.                     1.68e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
req_colmn2 = ["inp1", "inp3", "inp2", "inp4", "inp5"]

sklearn.feature_selection.f_regression(df[req_colmn2], df["op"], center=True)
# Out:
# (array([  5.81506304e+02,   1.72079226e+02,   3.45325515e+00,
#          3.96239137e+01,   5.67081558e-01]),
#  array([  7.59457809e-80,   6.38229056e-33,   6.38654442e-02,
#          8.14000103e-10,   4.51866160e-01]))

# %%
import sklearn
from sklearn import linear_model
reg1 = linear_model.LinearRegression()
reg1.fit(train_X, train_Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)

# %%
print reg1.score(X_test, Y_test)
# Out:
# 0.917216380895

# %%
reg4 = linear_model.Lasso(alpha = 0.001)
reg4.fit(train_X, train_Y)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute='auto', tol=0.0001,
#    warm_start=False)

# %%
print reg4.score(X_test, Y_test)
# Out:
# 0.917216377715

# %%
reg5 = linear_model.LassoLars(alpha=.001)
reg5.fit(train_X, train_Y)
# Out:
# LassoLars(alpha=0.001, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      precompute='auto', verbose=False)

# %%
print reg5.score(X_test, Y_test)
# Out:
# 0.917215674412

# %%
def MahalanobisDist(x, y):
    covariance_xy = np.cov(x,y, rowvar=0)
    inv_covariance_xy = np.linalg.inv(covariance_xy)
    xy_mean = np.mean(x),np.mean(y)
    x_diff = np.array([x_i - xy_mean[0] for x_i in x])
    y_diff = np.array([y_i - xy_mean[1] for y_i in y])
    diff_xy = np.transpose([x_diff, y_diff])
    
    md = []
    for i in range(len(diff_xy)):
        md.append(np.sqrt(np.dot(np.dot(np.transpose(diff_xy[i]),inv_covariance_xy),diff_xy[i])))
    return md

# %%
def MD_removeOutliers(x, y):
    MD = MahalanobisDist(x, y)
    threshold = np.mean(MD) * 10 
    outliers = []
    for i in range(len(MD)):
        if MD[i] > threshold:           
            outliers.append(i) 
    return (np.array(outliers))

# %%
Outl = MD_removeOutliers(df["inp4"], df["op"])
print Outl
# Out:
# [251]

# %%
df["inp4"][251]
# Out:
# 3727.8365529203443

# %%
df2 = df[df.inp4 <= 1500]

# %%
plt.scatter(df2["inp4"], df2["op"])

# %%
import statsmodels.formula.api as smf
mod6 = smf.wls(formula='op ~ inp1 + inp2 + inp3', data=df2)

# %%
reg6 = mod6.fit()
print reg.summary()
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                     op   R-squared:                       0.917
# Model:                            WLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                     1097.
# Date:                Fri, 23 May 2014   Prob (F-statistic):          5.86e-160
# Time:                        17:24:12   Log-Likelihood:                -2451.4
# No. Observations:                 300   AIC:                             4911.
# Df Residuals:                     296   BIC:                             4926.
# Df Model:                           3
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -3975.1079    585.733     -6.787      0.000     -5127.837 -2822.378
# inp1          42.2419      0.945     44.698      0.000        40.382    44.102
# inp2          32.1242     12.786      2.513      0.013         6.962    57.286
# inp3          57.0695      1.614     35.353      0.000        53.893    60.246
# ==============================================================================
# Omnibus:                        0.998   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.607   Jarque-Bera (JB):                0.733
# Skew:                           0.051   Prob(JB):                        0.693
# Kurtosis:                       3.219   Cond. No.                     1.68e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
predict6 = mod6.predict(X_test, Y_test)

# %%
print predict6
# Out:
# [ 74180274.5  31027860.   23830259.5]

# %%
from sklearn.feature_selection import SelectPercentile, f_classif
import pylab as pl

X_indices = np.arange(train_X.shape[-1])
selector = SelectPercentile(f_classif, percentile=10)
selector.fit(train_X, train_Y)
scores = -np.log10(selector.pvalues_)
scores /= scores.max()
plt.bar(X_indices,  scores, width=.2,
       label=r'Univariate score ($-Log(p_{value})$)', color='g')
# Out:
# <Container object of 3 artists>

# %%
com = ["inp1","inp2", "inp3"]
c = polyfit(df["op"], df[com],1)
print c
# Out:
# [[  1.38331978e-02   1.22168439e-04   5.60023091e-03]
#  [  4.91317198e+01   4.48901090e+01   1.66974503e+01]]

# %%
plt.plot(c)
# Out:
# [<matplotlib.lines.Line2D at 0x1a81c570>,
#  <matplotlib.lines.Line2D at 0x1a81c750>,
#  <matplotlib.lines.Line2D at 0x1a81c8f0>]

# %%
reg5 = linear_model.LassoLars(alpha=.000000000000000000000000000000000000000000000001)
reg5.fit(train_X, train_Y)
# Out:
# LassoLars(alpha=1e-48, copy_X=True, eps=2.2204460492503131e-16,
#      fit_intercept=True, fit_path=True, max_iter=500, normalize=True,
#      precompute='auto', verbose=False)

# %%
print reg5.score(X_test, Y_test)
# Out:
# 0.917216380895

# %%
from sklearn import neighbors

n_neighbors = 4

knn = neighbors.KNeighborsRegressor(n_neighbors, weights="uniform", metric = "euclidean")
reg12 = knn.fit(train_X, train_Y)

# %%
print reg12.score(X_test, Y_test)
# Out:
# 0.983318603885

# %%
print reg12.predict(X_test).astype(int)
# Out:
# [ 6136   917  4405  2308  4874 11470  1420  5727  2730  7717  7330  5045
#    853  4985   871  7193  5333 11985  5222  7753  2189  6164  7291  8642
#   2869  4200  3018 10355  7655  5856  4121  5288  3305  5839  6402  5200
#  10668  1541  1538  5552  1567  9353  2081  8131  9552  3907  8876  1651
#   7111  4761  5913  8414  2615 12515  1858  8141  5489  9947  6852  9940
#   4624  8206  2572  5095  4291  4653  9352  1923  2177  4121  8414  2290
#   7605  7144  3354  5626  5340  6038  5134  2963  6666  9224  9432 10197
#   2100  3486  6009  3317  7157  1248  1924  1420  3032  6578  3317  5597
#   3438  2260  1737]

# %%
print sklearn.metrics.mean_squared_error(Y_test, reg12.predict(X_test))
print sklearn.metrics.mean_absolute_error(Y_test, reg12.predict(X_test))
print sklearn.metrics.explained_variance_score(Y_test, reg12.predict(X_test))
# Out:
# 137892.54577
# 305.472222222
# 0.983502176497

# %%
plt.scatter(reg12.predict(X_test), Y_test)
