# %%
import numpy as np
import pandas as pd
df = pd.ExcelFile("D:\\R dir\\World_Poverty_Analysis\\Custom Data.xlsx")
df = df.parse("Sheet1",index_col=None, na_values=['NA'])
df.head()
# Out:
#    Year   GNI  Population           GDP  Life_Expectancy  Poverty_Gap  \
# 0  1995  1530   955804355  366599645571               60          NaN
# 1  1996  1640   973147577  399786888571               61          NaN
# 2  1997  1710   990460131  423160419466               61          NaN
# 3  1998  1800  1007746556  428741030221               61          NaN
# 4  1999  1960  1025014711  466867079633               62          NaN
#
#    Poverty_HCR(National)  Poverty_HCR(Urban)  Poverty_HCR(Rural)  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
#
#    Battle_Related_Deaths  Net_Enrollment_Rate(Primary)  Access_to_electricity  \
# ...

# %%
df.describe()
# Out:
#               Year          GNI    Population           GDP  Life_Expectancy  \
# count    18.000000    18.000000  1.800000e+01  1.800000e+01        18.000000
# mean   2003.500000  2908.333333  1.099603e+09  8.876898e+11        63.388889
# std       5.338539  1163.338249  8.845158e+07  5.281592e+11         1.914001
# min    1995.000000  1530.000000  9.558044e+08  3.665996e+11        60.000000
# 25%    1999.250000  1980.000000  1.029326e+09  4.693026e+11        62.000000
# 50%    2003.500000  2540.000000  1.102206e+09  6.699710e+11        63.500000
# 75%    2007.750000  3762.500000  1.170771e+09  1.235049e+12        65.000000
# max    2012.000000  5080.000000  1.236687e+09  1.880097e+12        66.000000
#
#        Poverty_Gap  Poverty_HCR(National)  Poverty_HCR(Urban)  \
# count     2.000000               3.000000            3.000000
# mean     26.500000              29.666667           20.333333
# std       3.535534               7.505553            6.027714
# ...

# %%
df.corr()
# Out:
#                                   Year       GNI  Population       GDP  \
# Year                          1.000000  0.973916    0.999717  0.939248
# GNI                           0.973916  1.000000    0.968452  0.990840
# Population                    0.999717  0.968452    1.000000  0.931344
# GDP                           0.939248  0.990840    0.931344  1.000000
# Life_Expectancy               0.987304  0.950570    0.988394  0.916055
# Poverty_Gap                  -1.000000 -1.000000   -1.000000 -1.000000
# Poverty_HCR(National)        -0.960769 -0.956634   -0.960117 -0.910698
# Poverty_HCR(Urban)           -0.943256 -0.938328   -0.942476 -0.885474
# Poverty_HCR(Rural)           -0.970725 -0.967130   -0.970160 -0.925912
# Battle_Related_Deaths        -0.287123 -0.420605   -0.273228 -0.480233
# Net_Enrollment_Rate(Primary)  0.932022  0.910257    0.936402  0.894454
# Access_to_electricity              NaN       NaN         NaN       NaN
# ...

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.scatter(df["Year"],df["Emp_to_pop_ratio"])

# %%
plt.scatter(df["Year"], df["Poverty_HCR(National)"])

# %%
plt.scatter(df["Year"], df["Battle_Related_Deaths"])

# %%
plt.scatter(df["Battle_Related_Deaths"], df["Poverty_HCR(National)"])

# %%
plt.scatter(df["GNI"], df["Poverty_HCR(National)"])

# %%
ax = plt.scatter(df["Year"], df["GNI"],color='red', alpha=1, s = df["Poverty_HCR(National)"]*50, facecolor = "white")

#plt.scatter(Vir_runs, Vir_balls,  color='red', alpha=0.5, s= Vir_fours*100, facecolor = "white")

# %%
plt.scatter(df["Year"], df["Battle_Related_Deaths"],color='red', alpha=1, s = df["Poverty_HCR(National)"]*20, facecolor = "white")

# %%
req_colmn = ["GNI","Year", "Population", "GDP", "Life_Expectancy", "Battle_Related_Deaths", "Net_Enrollment_Rate(Primary)", "Primary_Comp_Rate", "Unempl_Primary"]

#"Poverty Gap", "Poverty HCR(National)"

train_X = df[req_colmn]
train_Y = df["Poverty_HCR(National)"]

df["Net_Enrollment_Rate(Primary)"] = df["Net_Enrollment_Rate"]
df["Poverty_HCR(National)"] = df["Poverty_HCR"]

# %% [markdown]
# <h1> Information about the data set </h1>
# MPPS - Male PRimary PS
# MPALL - Male Primary All
# <br></br>
# <p>PS : Principal status
# Primary sector : Agriculture and allied activities
# Secondary sector : Mining and quarrying , Manufacturing, Electricity, water, etc. and Construction
# Tertiary sector : Trade, hotel and restuarant, Transport,storage and communication and Other services.
# Note : Data on NSS rounds 38, 43, 50, 55, 61 and 66 relate to quinquennial rounds.
# Source : National Sample Survey Organisation, Ministry of Statistics and Programme Implementation, Government of India.</p>
# <br></br>
# <p>Employment Situation in India - Per 1000 Distribution of Usually Employed by Broad Groups of Industry for Various Rounds</p>
#
# Similarly, there are Male Secondary (MS), Male Tertiary, Female Primary, Female Secondary, Female Tertiary.
# <br></br>

# %%
df2 = pd.ExcelFile("D:\\R dir\\World_Poverty_Analysis\\RBI_Data.xls")
df2 = df2.parse("rural",index_col=None, na_values=['NA'])
df2.head()
# Out:
#    Round          Survey Period  MPPS  MPALL  MSPS  MSALL  MTPS  MTALL  FPPS  \
# 0     38  January-December 1983   772    775   102    100   123    122   862
# 1     43    July 1987-June 1988   739    745   123    121   138    134   825
# 2     45   July 1989 -June 1990   716    717   120    121   164    162   800
# 3     46    July 1990-June 1991   705    710   123    121   172    169   842
# 4     47     July-December 1991   748    749   112    112   140    139   859
#
#    FPALL  FSPS  FSALL  FTPS  FSALL.1
# 0    875    78     74    57       48
# 1    847   112    100    63       53
# 2    814   130    124    70       61
# 3    849    83     81    75       70
# 4    863    79     79    62       58
#
# [5 rows x 14 columns]

# %%
df2.describe()
# Out:
#           Round        MPPS       MPALL       MSPS       MSALL        MTPS  \
# count  23.00000   23.000000   23.000000   23.00000   23.000000   23.000000
# mean   54.00000  705.869565  708.869565  134.73913  133.304348  159.304348
# std     7.70478   48.912077   48.596955   31.45013   31.120637   19.848139
# min    38.00000  592.000000  594.000000  102.00000  100.000000  123.000000
# 25%    48.50000  667.000000  671.500000  111.00000  110.500000  141.000000
# 50%    54.00000  712.000000  714.000000  123.00000  121.000000  161.000000
# 75%    59.50000  748.500000  749.500000  152.50000  150.000000  177.500000
# max    68.00000  772.000000  775.000000  221.00000  220.000000  187.000000
#
#             MTALL        FPPS       FPALL        FSPS       FSALL        FTPS  \
# count   23.000000   23.000000   23.000000   23.000000   23.000000   23.000000
# mean   157.608696  832.652174  844.826087  100.086957   96.391304   67.130435
# ...

# %%
plt.plot(df2["MPALL"])

# %%
plt.plot(df2["MSALL"])

# %% [markdown]
# <h2> Inferences from the dataset </h2>
#
# <ul>
# <li> The poverty rate in India is decreasing, as infered by the World Bank and the RBI data. </li>
# <li> The sanitation facilities, and the water source availability have been improving steadily, which might have been the reason for urban migration in India. </li>
# <li> The variable sanitation facilities and availability of water resources are correlated. GDP, GNI are also correlated. </li>
# </ul>
#
# <h3> But, is poverty really decreasing at a rate the data is depicting? </h3>
#
# <p> There is a danger of the poverty count again raising, because the data suggests that there is a steep decline in the agricultural employment, which in turn contributes to a steep increase in the type-2 and type-3 employment. So, from this, it can be infered that due to mechanization of agricultural equipment, people are migrating from the rural areas to the urban areas due to the decline of employment opportunities in the agricultural domain. So, this results in a flow of population from the rural areas to the urban areas. </p>
#
# <p> But on the other hand, due to the increase of population, and in turn the population density, the employment opportunities are decreasing. The fact that about 65-67% (infered from World bank data) of the Indian Population consists of youth, suggests that the unemployment rate is bound to increase further. </p>
#
# <p> As the data is keenly observed, the unemployed population per total population ratio is steadily increasing, which means that, for the years to come, the ratio is bound to increase. </p>
#
# <p> This data on the unemployment rate of the respective India states gives a rough picture that, in an overall perspective, the unemployment rate has been decreasing.
# But on careful observation, it can be infered that the states, which lie in the top percentile with respect to the total population, have their unemployment rate increasing as opposed to the ones in the lower quantile
# This phenomenon supports the above inference, which chalks out a relationship between the population of the state(%change) and the employment rate. </p>
# <p>[Data Source] (http://pib.nic.in/newsite/erelease.aspx?relid=82928)
#                   (http://www.rbi.org.in/)</p>
