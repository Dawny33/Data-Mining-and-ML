# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly
import seaborn as sb
import statsmodels.formula.api as smf
import csv

df = pd.ExcelFile("D:\\R dir\\TN District Economy Analysis\\curated.xls")

df = df.parse("Sheet1",index_col=None, na_values=['NA'])
df.head()
print df.shape
# Out:
# (32, 12)

# %%
df.columns  = df.columns.map(lambda x: x.lower())

# %%
df
# Out:
#           area_name  total_persons(2011)  total_males  total_females  \
# 0       Thiruvallur              3728104      1876062        1852042
# 1           Chennai              4646732      2335844        2310888
# 2      Kancheepuram              3998252      2012958        1985294
# 3           Vellore              3936331      1961688        1974643
# 4    Tiruvannamalai              2464875      1235889        1228986
# 5        Viluppuram              3458873      1740819        1718054
# 6             Salem              3482056      1781571        1700485
# 7          Namakkal              1726601       869280         857321
# 8             Erode              2251744      1129868        1121876
# 9      The Nilgiris               735394       360143         375251
# 10         Dindigul              2159775      1080938        1078837
# 11            Karur              1064493       528184         536309
# 12  Tiruchirappalli              2722290      1352284        1370006
# 13       Perambalur               565223       282157         283066
# 14         Ariyalur               754894       374703         380191
# 15        Cuddalore              2605914      1311697        1294217
# 16     Nagapattinam              1616450       798127         818323
# 17       Thiruvarur              1264277       626693         637584
# 18        Thanjavur              2405890      1182416        1223474
# 19      Pudukkottai              1618345       803188         815157
# 20        Sivaganga              1339101       668672         670429
# 21          Madurai              3038252      1526475        1511777
# 22            Theni              1245899       625683         620216
# 23     Virudhunagar              1942288       967709         974579
# 24   Ramanathapuram              1353445       682658         670787
# 25     Thoothukkudi              1750176       865021         885155
# 26      Tirunelveli              3077233      1520912        1556321
# 27    Kanniyakumari              1870374       926345         944029
# 28       Dharmapuri              1506843       774303         732540
# 29      Krishnagiri              1879809       960232         919577
# 30       Coimbatore              3458045      1729297        1728748
# 31         Tiruppur              2479052      1246159        1232893
#
#     rural_persons  rural_males  rural_females  urban_persons  urban_males  \
# 0         1299709       650462         649247        2428395      1225600
# 1               0            0              0        4646732      2335844
# 2         1459916       734979         724937        2538336      1277979
# 3         2234344      1117101        1117243        1701987       844587
# 4         1969930       989726         980204         494945       246163
# 5         2939785      1481475        1458310         519088       259344
# 6         1707934       883274         824660        1774122       898297
# 7         1030476       520684         509792         696125       348596
# 8         1093768       552393         541375        1157976       577475
# 9          299739       145909         153830         435655       214234
# 10        1351735       678605         673130         808040       402333
# 11         629976       312628         317348         434517       215556
# 12        1384257       688552         695705        1338033       663732
# 13         468060       233926         234134          97163        48231
# 14         671100       333253         337847          83794        41450
# 15        1720725       868861         851864         885189       442836
# 16        1251826       619369         632457         364624       178758
# 17        1006482       499954         506528         257795       126739
# 18        1554531       765177         789354         851359       417239
# 19        1301991       645505         656486         316354       157683
# 20         926256       462210         464046         412845       206462
# 21        1191451       601247         590204        1846801       925228
# 22         575418       290880         284538         670481       334803
# 23         962062       480360         481702         980226       487349
# 24         942746       474508         468238         410699       208150
# 25         873374       430361         443013         876802       434660
# 26        1557004       768728         788276        1520229       752184
# 27         330572       164938         165634        1539802       761407
# 28        1245931       643215         602716         260912       131088
# 29        1451446       742444         709002         428363       217788
# 30         839105       419032         420073        2618940      1310265
# 31         957941       479309         478632        1521111       766850
#
#     urban_females  gdp(2011)  total_persons(2001)
# 0         1202795      39924              2754756
# 1         2310888      91749              4343645
# 2         1260357      46376              2877468
# 3          857400      21379              3477317
# 4          248782       9575              2186125
# 5          259744      10060              2960373
# 6          875825      19451              3016346
# 7          347529      10338              1493462
# 8          580501      14172              2581500
# 9          221421       5130               762141
# 10         405707       8910              1923014
# 11         218961       5950               935686
# 12         674301      21391              2418366
# 13          48932       2170               493646
# 14          42344       2776               695524
# 15         442353      10854              2285395
# 16         185866       8187              1488839
# 17         131056       6654              1169474
# 18         434120      14337              2216138
# 19         158671       7215              1459601
# 20         206383       4799              1155356
# 21         921573      18328              2578201
# 22         335678       5182              1093950
# 23         492877       7786              1751301
# 24         202549       4864              1187604
# 25         442142       7636              1572273
# 26         768045      13394              2723988
# 27         778395      11380              1676034
# 28         129824       5021              2856300
# 29         210575       6648               512859
# 30        1308675      35411              4271856
# 31         754261      21820               677978
#
# [32 rows x 12 columns]

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import plotly.plotly as py
from plotly.graph_objs import *

fig6 = plt.figure()

py.sign_in("Dawny33", "asnr4fvsob")

data = Data([
    Bar(
        x=df["area name"],
        y=df["gdp(2011)"]
    )
])


plot_url = py.plot(data)
plt.show()

# %%
p = np.percentile(df["total_persons(2011)"], 75)

top_perc = df[df["total_persons(2011)"] >= p]

top_perc
# Out:
#        area_name  total_persons(2011)  total_males  total_females  \
# 0    Thiruvallur              3728104      1876062        1852042
# 1        Chennai              4646732      2335844        2310888
# 2   Kancheepuram              3998252      2012958        1985294
# 3        Vellore              3936331      1961688        1974643
# 5     Viluppuram              3458873      1740819        1718054
# 6          Salem              3482056      1781571        1700485
# 26   Tirunelveli              3077233      1520912        1556321
# 30    Coimbatore              3458045      1729297        1728748
#
#     rural_persons  rural_males  rural_females  urban_persons  urban_males  \
# 0         1299709       650462         649247        2428395      1225600
# 1               0            0              0        4646732      2335844
# 2         1459916       734979         724937        2538336      1277979
# 3         2234344      1117101        1117243        1701987       844587
# 5         2939785      1481475        1458310         519088       259344
# 6         1707934       883274         824660        1774122       898297
# 26        1557004       768728         788276        1520229       752184
# 30         839105       419032         420073        2618940      1310265
#
#     urban_females  gdp(2011)  total_persons(2001)
# 0         1202795      39924              2754756
# 1         2310888      91749              4343645
# 2         1260357      46376              2877468
# 3          857400      21379              3477317
# 5          259744      10060              2960373
# 6          875825      19451              3016346
# 26         768045      13394              2723988
# 30        1308675      35411              4271856
#
# [8 rows x 12 columns]

# %%
q = np.percentile(df["total_persons(2011)"], 95)

outlier = df[df["total_persons(2011)"] >= q]
outlier
# Out:
#       area_name  total_persons(2011)  total_males  total_females  \
# 1       Chennai              4646732      2335844        2310888
# 2  Kancheepuram              3998252      2012958        1985294
#
#    rural_persons  rural_males  rural_females  urban_persons  urban_males  \
# 1              0            0              0        4646732      2335844
# 2        1459916       734979         724937        2538336      1277979
#
#    urban_females  gdp(2011)  total_persons(2001)
# 1        2310888      91749              4343645
# 2        1260357      46376              2877468
#
# [2 rows x 12 columns]

# %%
q1 = np.percentile(df["total_persons(2011)"], 15)

outlier2 = df[df["total_persons(2011)"] <= q1]
outlier2
# Out:
#        area_name  total_persons(2011)  total_males  total_females  \
# 9   The Nilgiris               735394       360143         375251
# 11         Karur              1064493       528184         536309
# 13    Perambalur               565223       282157         283066
# 14      Ariyalur               754894       374703         380191
# 22         Theni              1245899       625683         620216
#
#     rural_persons  rural_males  rural_females  urban_persons  urban_males  \
# 9          299739       145909         153830         435655       214234
# 11         629976       312628         317348         434517       215556
# 13         468060       233926         234134          97163        48231
# 14         671100       333253         337847          83794        41450
# 22         575418       290880         284538         670481       334803
#
#     urban_females  gdp(2011)  total_persons(2001)
# 9          221421       5130               762141
# 11         218961       5950               935686
# 13          48932       2170               493646
# 14          42344       2776               695524
# 22         335678       5182              1093950
#
# [5 rows x 12 columns]

# %%
p = np.percentile(df["total_persons(2001)"], 95)

outlier3 = df[df["total_persons(2001)"] >= p]
outlier3
# Out:
#      area_name  total_persons(2011)  total_males  total_females  \
# 1      Chennai              4646732      2335844        2310888
# 30  Coimbatore              3458045      1729297        1728748
#
#     rural_persons  rural_males  rural_females  urban_persons  urban_males  \
# 1               0            0              0        4646732      2335844
# 30         839105       419032         420073        2618940      1310265
#
#     urban_females  gdp(2011)  total_persons(2001)
# 1         2310888      91749              4343645
# 30        1308675      35411              4271856
#
# [2 rows x 12 columns]

# %%
p1 = np.percentile(df["total_persons(2001)"], 15)

outlier4 = df[df["total_persons(2001)"] <= p1]
outlier4
# Out:
#        area_name  total_persons(2011)  total_males  total_females  \
# 9   The Nilgiris               735394       360143         375251
# 13    Perambalur               565223       282157         283066
# 14      Ariyalur               754894       374703         380191
# 29   Krishnagiri              1879809       960232         919577
# 31      Tiruppur              2479052      1246159        1232893
#
#     rural_persons  rural_males  rural_females  urban_persons  urban_males  \
# 9          299739       145909         153830         435655       214234
# 13         468060       233926         234134          97163        48231
# 14         671100       333253         337847          83794        41450
# 29        1451446       742444         709002         428363       217788
# 31         957941       479309         478632        1521111       766850
#
#     urban_females  gdp(2011)  total_persons(2001)
# 9          221421       5130               762141
# 13          48932       2170               493646
# 14          42344       2776               695524
# 29         210575       6648               512859
# 31         754261      21820               677978
#
# [5 rows x 12 columns]

# %%
pal = sb.blend_palette(["seagreen", "lightblue"], 4)

sb.boxplot(df["total_persons(2011)"], names="2011",  color=pal, alpha = 0.2, fliersize=8, linewidth=1.5, widths=0.3, label="Outlier Analysis of ppopulation(2011)" )

# %%
pal = sb.blend_palette(["seagreen", "lightblue"], 4)

sb.boxplot(df["total_persons(2001)"], names="2001",  color=pal, alpha = 0.2, fliersize=8, linewidth=1.5, widths=0.3, label="Outlier Analysis of ppopulation(2001)" )

# %%
sb.set(style="darkgrid")

color = sb.color_palette()[2]
g = sb.jointplot("total_persons(2001)", "total_persons(2011)", data=df,
                  color=color, size=7)
#g.ax_joint.set(xlim=(0, 70), ylim=(0, 12))

# %%
pop_change = (df["total_persons(2011)"] - df["total_persons(2001)"])/df["total_persons(2011)"]

# %%
popch_dict = {"Name":df["area_name"], "Change":pop_change}

df_pop = pd.DataFrame(popch_dict)
df_pop
# Out:
#       Change             Name
# 0   0.261084      Thiruvallur
# 1   0.065226          Chennai
# 2   0.280318     Kancheepuram
# 3   0.116610          Vellore
# 4   0.113089   Tiruvannamalai
# 5   0.144122       Viluppuram
# 6   0.133746            Salem
# 7   0.135028         Namakkal
# 8  -0.146445            Erode
# 9  -0.036371     The Nilgiris
# 10  0.109623         Dindigul
# 11  0.121003            Karur
# 12  0.111643  Tiruchirappalli
# 13  0.126635       Perambalur
# 14  0.078647         Ariyalur
# 15  0.122997        Cuddalore
# 16  0.078945     Nagapattinam
# 17  0.074986       Thiruvarur
# 18  0.078870        Thanjavur
# 19  0.098090      Pudukkottai
# 20  0.137215        Sivaganga
# 21  0.151420          Madurai
# 22  0.121959            Theni
# 23  0.098331     Virudhunagar
# 24  0.122533   Ramanathapuram
# 25  0.101649     Thoothukkudi
# 26  0.114793      Tirunelveli
# 27  0.103904    Kanniyakumari
# 28 -0.895552       Dharmapuri
# 29  0.727175      Krishnagiri
# 30 -0.235338       Coimbatore
# 31  0.726517         Tiruppur
#
# [32 rows x 2 columns]

# %%
z_score2011 = (df["total_persons(2011)"] - np.mean(df["total_persons(2011)"]))/np.std(df["total_persons(2011)"])
z_score2011
# Out:
# 0     1.415171
# 1     2.297429
# 2     1.674624
# 3     1.615154
# 4     0.201955
# 5     1.156599
# 6     1.178865
# 7    -0.507090
# 8    -0.002738
# 9    -1.459054
# 10   -0.091066
# 11   -1.142984
# 12    0.449179
# 13   -1.622487
# 14   -1.440326
# 15    0.337410
# 16   -0.612880
# 17   -0.951110
# 18    0.145305
# 19   -0.611060
# 20   -0.879248
# 21    0.752631
# 22   -0.968760
# 23   -0.299942
# 24   -0.865472
# 25   -0.484448
# 26    0.790069
# 27   -0.369009
# 28   -0.718147
# 29   -0.359947
# 30    1.155804
# 31    0.215571
# Name: total_persons(2011), dtype: float64

# %%
z_score2001 = (df["total_persons(2001)"] - np.mean(df["total_persons(2001)"]))/np.std(df["total_persons(2001)"])
z_score2001
# Out:
# 0     0.755205
# 1     2.318915
# 2     0.875972
# 3     1.466316
# 4     0.195585
# 5     0.957563
# 6     1.012649
# 7    -0.486102
# 8     0.584694
# 9    -1.205834
# 10   -0.063357
# 11   -1.035039
# 12    0.424145
# 13   -1.470074
# 14   -1.271395
# 15    0.293282
# 16   -0.490652
# 17   -0.804956
# 18    0.225122
# 19   -0.519426
# 20   -0.818850
# 21    0.581448
# 22   -0.879283
# 23   -0.232349
# 24   -0.787113
# 25   -0.408540
# 26    0.724924
# 27   -0.306423
# 28    0.855140
# 29   -1.451166
# 30    2.248264
# 31   -1.288663
# Name: total_persons(2001), dtype: float64

# %%
z_score_diff = (z_score2011 - z_score2001)/z_score2011
#z_score_diff

# %%
count = 0
for i in z_score2011:
    if i<0:
        count += 1
        
print count
print np.max(z_score2011)
# Out:
# 18
# 2.29742949274

# %%
count2 = 0
for j in z_score2001:
    if j<0:
        count2 += 1
        
print count2
print np.max(z_score2001)
# Out:
# 17
# 2.31891531205

# %%
z_score.to_csv('D:\\R dir\\TN District Economy Analysis\\z_score(2011).csv')

# %%
z_score.to_csv('D:\\R dir\\TN District Economy Analysis\\z_score(2001).csv')

# %%
df_2001 = pd.ExcelFile("D:\\R dir\\TN District Economy Analysis\\TamilNadu_2001.xlsx")
df_2011 = pd.ExcelFile("D:\\R dir\\TN District Economy Analysis\\TamilNadu_2011.xlsx")

df_2001 = df_2001.parse("Sheet3",index_col=None, na_values=['NA'])
df_2011 = df_2011.parse("Sheet2",index_col=None, na_values=['NA'])

print df_2001.shape
print df_2011.shape
# Out:
# (32, 58)
# (32, 88)

# %%
#z_score2011
#z_score2001

sb.kdeplot(z_score2011, shade = True)

# %%
sb.kdeplot(z_score2001, shade = True)

# %%
z_score_dict = {"2001":z_score2001, "2011":z_score2011}
z_score_df = pd.DataFrame(z_score_dict)
sb.lmplot("2001", "2011", z_score_df)
