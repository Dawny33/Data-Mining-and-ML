# %%
from IPython.display import Image

Image(filename='/Users/jalemrajrohit/Desktop/Data Science/Churn_Analysis/Churn_Plot_forAll_Customers.png')

# %% [markdown]
# ### The above graph is the complete churn graph for all the customers; which clearly exhibit 3 clusters.
#
# > One around the (0 - 10) seats limit; which might be startups. The fact that the cluster is thick at the bottom and gets thinner as we go up portrays that churn is pre-dominant in the 0-15 months span.  It might mean that the companies are not getting an immediate requirement for which they opted for a help desk.
#
# > However, the fact that the customers who bought more seats tend to stay longer with us, with a  healthy slope of 0.24532551. A very good sign.
#
# > The second cluster is at the 30 seat mark.

# %%
Image(filename='/Users/jalemrajrohit/Desktop/Data Science/Churn_Analysis/Churn_Plot_for_Greater_than_30seats.png')

# %% [markdown]
# ### Let's zoom into the second half of the graph (Customers with >30 seats.)
#
# > Suddenly, the relation between the seats and the age exhibits a negative relation. With a slope of -0.0538769.
#
# > On close observation, even this graph has a significant chunk of customers who have churned within the 0-15 month span.
#
# > The customer who churned at the age of ~45 with 40 seats should be paid attention to. That is a dedicated customer lost.

# %% [markdown]
# # Something to ponder upon?
#
# Both the visualizations show a very similar behaviour, which is; the bulk of churned customers have churned out in the 0-15 month span; which means that one or more of their immediate requirements for opting for a help desk haven't been met.
#
# #####Solution:  Better entry surveys about expectations and understanding our buyer personas better?
