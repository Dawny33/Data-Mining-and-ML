# %%
import pandas as pd                                                                                                                                            
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.ExcelFile("C:\\Users\\acer\\Desktop\\Coursera-DSTK\\BTP\\arunachalpradesh.xlsx")
df = df.parse("t1",index_col=None, na_values=['NA'])
df.head()
# Out:
#       Level             Name  Area  No of Households  Total Population Person  \
# 0  DISTRICT           Tawang  2172             10062                    49977
# 1  DISTRICT      West Kameng  7422             18159                    83947
# 2  DISTRICT      East Kameng  4134             14508                    78690
# 3  DISTRICT       Papum Pare  3462             35730                   176573
# 4  DISTRICT  Upper Subansiri  7032             15869                    83448
#
#    Total Population Male  Total Population Female  \
# 0                  29151                    20826
# 1                  46155                    37792
# 2                  38775                    39915
# 3                  89182                    87391
# 4                  41758                    41690
#
#    Population in the age group 0-6 Person  \
# 0                                    5788
# 1                                   11643
# 2                                   14626
# 3                                   25170
# 4                                   12475
#
#    Population in the age group 0-6 Male  \
# 0                                  2914
# 1                                  5900
# 2                                  7311
# 3                                 12729
# 4                                  6332
#
#    Population in the age group 0-6 Female  Scheduled Tribes population Person  \
# 0                                    2874                               34811
# 1                                    5743                               46380
# 2                                    7315                               72400
# 3                                   12441                              117216
# 4                                    6143                               78323
#
#    Scheduled Tribes population Male  Scheduled Tribes population Female  \
# 0                             16770                               18041
# 1                             22771                               23609
# 2                             35266                               37134
# 3                             56469                               60747
# 4                             38570                               39753
#
#    Literates Population Person  Literates Population Male  \
# 0                        26073                      17720
# 1                        48492                      29566
# 2                        38449                      21599
# 3                       121048                      65794
# 4                        45278                      24807
#
#    Literates Population Female  Illiterate Persons  Illiterate Male  \
# 0                         8353               23904            11431
# 1                        18926               35455            16589
# 2                        16850               40241            17176
# 3                        55254               55525            23388
# 4                        20471               38170            16951
#
#    Illiterate Female  Total Worker Population Person
# 0              12473                           28561 ...
# 1              18866                           42493 ...
# 2              23065                           31710 ...
# 3              32137                           65772 ...
# 4              21219                           33370 ...
#
# [5 rows x 85 columns]

# %%
df.columns  = df.columns.map(lambda x: x.lower())
#print df.columns

split_col_name = df.columns.map(lambda x: x.sp#lit(' '))
#print df.columns
print df.shape
# Out:
# (16, 85)

# %%
names = ('Tawang', 'W Kameng', 'E Kameng', 'Papum Pare', 'U Subansiri', 'W Siang', 'E Siang', 'U Siang', 'Changlang', 'Tirap', 'L Subansiri', 'Kurung V', 'Dibang V','L. Dibang V', 'Lohit','Anjaw')
y_pos = np.arange(len(names))
population = df["Total Population Person"]

plt.barh(y_pos, population, align='center', alpha=0.4)
plt.yticks(y_pos, names)
plt.xlabel('Total Population')
plt.title('Population Analysis')

plt.show()

# %%
print df.columns
# Out:
# Index([u'Level', u'Name', u'Area', u'No of Households', u'Total Population Person', u'Total Population Male', u'Total Population Female', u'Population in the age group 0-6 Person', u'Population in the age group 0-6 Male', u'Population in the age group 0-6 Female', u'Scheduled Tribes population Person', u'Scheduled Tribes population Male', u'Scheduled Tribes population Female', u'Literates Population Person', u'Literates Population Male', u'Literates Population Female', u'Illiterate Persons', u'Illiterate Male', u'Illiterate Female', u'Total Worker Population Person', u'Total Worker Population Male', u'Total Worker Population Female', u'Main Working Population Person', u'Main Working Population Male', u'Main Working Population Female', u'Main Cultivator Population Person', u'Main Cultivator Population Male', u'Main Cultivator Population Female', u'Main Agricultural Labourers Population Person', u'Main Agricultural Labourers Population Male', u'Main Agricultural Labourers Population Female', u'Main Household Industries Population Person', u'Main Household Industries Population Male', u'Main Household Industries Population Female', u'Main Other Workers Population Person', u'Main Other Workers Population Male', u'Main Other Workers Population Female', u'Marginal Worker Population Person', u'Marginal Worker Population Male', u'Marginal Worker Population Female', u'Marginal Cultivator Population Person', u'Marginal Cultivator Population Male', u'Marginal Cultivator Population Female', u'Marginal Agriculture Labourers Population Person', u'Marginal Agriculture Labourers Population Male', u'Marginal Agriculture Labourers Population Female', u'Marginal Household Industries Population Person', u'Marginal Household Industries Population Male', u'Marginal Household Industries Population Female', u'Marginal Other Workers Population Person', u'Marginal Other Workers Population Male', u'Marginal Other Workers Population Female', u'Marginal Worker Population 3_6 Person', u'Marginal Worker Population 3_6 Male', u'Marginal Worker Population 3_6 Female', u'Marginal Cultivator Population 3_6 Person', u'Marginal Cultivator Population 3_6 Male', u'Marginal Cultivator Population 3_6 Female', u'Marginal Agriculture Labourers Population 3_6 Person', u'Marginal Agriculture Labourers Population 3_6 Male', u'Marginal Agriculture Labourers Population 3_6 Female', u'Marginal Household Industries Population 3_6 Person', u'Marginal Household Industries Population 3_6 Male', u'Marginal Household Industries Population 3-6 Female', u'Marginal Other Workers Population Person 3_6 Person', u'Marginal Other Workers Population Person 3_6 Male', u'Marginal Other Workers Population Person 3_6 Female', u'Marginal Worker Population 0_3 Person', u'Marginal Worker Population 0_3 Male', u'Marginal Worker Population 0_3_Female', u'Marginal Cultivator Population 0_3 Person', u'Marginal Cultivator Population 0_3 Male', u'Marginal Cultivator Population 0_3_Female', u'Marginal Agriculture Labourers Population 0_3 Person', u'Marginal Agriculture Labourers Population 0_3 Male', u'Marginal Agriculture Labourers Population 0_3 Female', u'Marginal Household Industries Population 0_3 Person', u'Marginal Household Industries Population 0_3 Male', u'Marginal Household Industries Population 0_3 Female', u'Marginal Other Workers Population 0_3 Person', u'Marginal Other Workers Population 0_3 Male', u'Marginal Other Workers Population 0_3 Female', u'Non Working Population Person', u'Non Working Population Male', u'Non Working Population Female'], dtype='object')
