# %%
import pandas as pd

# %%
train = pd.read_csv("/Users/jalemrajrohit/Desktop/Data Science/Kaggle/Winston_Challenge/train.csv")

train.head()

#len(train) # <-- 40000
#train.shape  # <-- (40000, 211)
# Out:
#    Id  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   1        NaN        NaN        NaN        NaN          8        NaN
# 1   2        NaN        NaN        NaN        NaN          3   0.388896
# 2   3        NaN  -0.696727   0.739591  -0.167928          9   0.471947
# 3   4        NaN  -0.694350   1.568248   0.479073          5   0.120653
# 4   5          6  -1.736489   2.765531   1.245280          7   4.866985
#
#    Feature_7  Feature_8  Feature_9       ...         Ret_175   Ret_176  \
# 0      75751     0.2254         11       ...       -0.002688  0.002246
# 1      17369     0.0166         13       ...       -0.000129  0.000123
# 2       8277     0.3650          9       ...       -0.000524 -0.000394
# 3      22508     0.2654         13       ...        0.000346 -0.000090
# 4      22423     0.2138         13       ...       -0.001235  0.000027
#
#     Ret_177       Ret_178   Ret_179   Ret_180  Ret_PlusOne  Ret_PlusTwo  \
# ...

# %%
test = pd.read_csv("/Users/jalemrajrohit/Desktop/Data Science/Kaggle/Winston_Challenge/test.csv")

test.head()
# Out:
#    Id  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   1        NaN  -0.479347   0.716679   0.765301          6        NaN
# 1   2        NaN  -1.556631  -0.544329  -0.041571          2  -0.401548
# 2   3        NaN  -1.124463   0.750519   0.801993          8   0.463234
# 3   4        NaN   2.404529   1.371021   1.135463          1   3.470399
# 4   5          1   0.180297  -0.107651  -0.272008          8   0.198879
#
#    Feature_7  Feature_8  Feature_9    ...      Ret_111   Ret_112   Ret_113  \
# 0      36450     0.2064         14    ...    -0.000135 -0.000002 -0.000144
# 1      77624     0.3418         10    ...    -0.000384 -0.000382  0.000387
# 2      44942     0.0166         11    ...    -0.000013  0.000801 -0.000278
# 3      35071     0.2208         12    ...    -0.002180  0.000206 -0.000053
# 4       1188     0.2254        NaN    ...    -0.000204  0.000176 -0.000204
#
#     Ret_114   Ret_115   Ret_116   Ret_117   Ret_118   Ret_119   Ret_120
# ...

# %%
sample = pd.read_csv("/Users/jalemrajrohit/Desktop/Data Science/Kaggle/Winston_Challenge/sample_submission.csv")

sample.head(30)
# Out:
#       Id  Predicted
# 0    1_1          0
# 1    1_2          0
# 2    1_3          0
# 3    1_4          0
# 4    1_5          0
# 5    1_6          0
# 6    1_7          0
# 7    1_8          0
# 8    1_9          0
# 9   1_10          0
# 10  1_11          0
# 11  1_12          0
# 12  1_13          0
# 13  1_14          0
# 14  1_15          0
# 15  1_16          0
# 16  1_17          0
# 17  1_18          0
# 18  1_19          0
# 19  1_20          0
# 20  1_21          0
# 21  1_22          0
# 22  1_23          0
# 23  1_24          0
# 24  1_25          0
# 25  1_26          0
# 26  1_27          0
# 27  1_28          0
# 28  1_29          0
# 29  1_30          0
